# %% [markdown]
# <a href="https://colab.research.google.com/github/paulowiz/uff_engenharia_de_dados_com_python/blob/master/uff_engenharia_de_dados_com_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tutorial pratico ETL (Extraction,Transformation,Loading)
#
# ## PT - Extração,Transformação e Carregamento de dados
#
#
# ### Problema a ser resolvido:
#
# O escritório de inovação de uma empresa precisa de um engenheiro de dados para fazer uma nova "Pipeline de Dados" para que eles possam ter acesso aos novos arquivos sobre patentes do setor publico de patentes dos Estados Unidos da America(USPTO).Com esses dados eles poderão fazer o download com o link facilidade e verificar quantos arquivos são processados diariamente.

# %% [markdown]
# # Extração de dados
#
# É o processo que analisa o provedor de dados, os tipos de dados que serão processados e faz a conexão com esse provedor através de REST API, Web Scrapping, SOAP etc.
#
# Em nosso caso, como nosso provider é o USPTO, não temos uma API deles para consumir esses dados.... então vamos utilizar a técnica de raspagem da web(Web Scrapping) que vamos pegar os dados direto do website.

# %%
import requests
from bs4 import BeautifulSoup


class Uspto:
    """Classe que extrai os dados sobre arquivos de patentes do USPTO"""

    def __init__(self, year):
        """
        Construtor que pega o ano como referência para iniciar a extração.
        """
        try:
            self.year = int(year)
        except:
            print('Year must be a number')
            return False
        self.link = 'https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/' + str(year) + '/'

    def get_uspto_files_information(self):
        headers = {
            "User-Agent":
                "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.102 Safari/537.36 Edge/18.19582"
        }

        page = requests.get(self.link, headers=headers)

        soup = BeautifulSoup(page.text, 'html.parser')

        soup = soup.find_all('table')
        soup = soup[-1]
        arr_files =[]
        trs = soup.find_all('tr')
        for tr in trs:
            tds = tr.find_all('td')
            dict_temp = {}
            try:
                dict_temp = {'filename': tds[0].text, 'size': tds[1].text, 'publish_on': tds[2].text, 'url': self.link+tds[0].find('a')['href']}
                arr_files.append(dict_temp)
            except:
                continue

        return arr_files

pass

# %% [markdown]
# ### Chamando a classe de extração que criamos acima

# %%
uspto = Uspto(2022)
files = uspto.get_uspto_files_information()
print(files)
# Out:
# [{'filename': 'ipa220106.zip', 'size': '163074754', 'publish_on': '2022-01-06 08:22', 'url': 'https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2022/ipa220106.zip'}, {'filename': 'ipa220113.zip', 'size': '159400377', 'publish_on': '2022-01-13 00:08', 'url': 'https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2022/ipa220113.zip'}, {'filename': 'ipa220120.zip', 'size': '143972032', 'publish_on': '2022-01-20 00:17', 'url': 'https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2022/ipa220120.zip'}, {'filename': 'ipa220127.zip', 'size': '172934663', 'publish_on': '2022-01-27 00:03', 'url': 'https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2022/ipa220127.zip'}, {'filename': 'ipa220203.zip', 'size': '174222902', 'publish_on': '2022-02-03 06:14', 'url': 'https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2022/ipa220203.zip'}, {'filename': 'ipa220210.zip', 'size': '162036524', 'publish_on': '2022-02-10 00:02', 'url': 'https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2022/ipa220210.zip'}, {'filename': 'ipa220217.zip', 'size': '143576934', 'publish_on': '2022-02-17 00:02', 'url': 'https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2022/ipa220217.zip'}, {'filename': 'ipa220224.zip', 'size': '158906116', 'publish_on': '2022-02-24 00:03', 'url': 'https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2022/ipa220224.zip'}, {'filename': 'ipa220303.zip', 'size': '199151005', 'publish_on': '2022-03-03 00:03', 'url': 'https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2022/ipa220303.zip'}, {'filename': 'ipa220310.zip', 'size': '170954180', 'publish_on': '2022-03-10 00:02', 'url': 'https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2022/ipa220310.zip'}, {'filename': 'ipa220317.zip', 'size': '165355543', 'publish_on': '2022-03-17 00:03', 'url': 'https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2022/ipa220317.zip'}, {'filename': 'ipa220324.zip', 'size': '190055188', 'publish_on': '2022-03-24 00:03', 'url': 'https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2022/ipa220324.zip'}, {'filename': 'ipa220331.zip', 'size': '183482817', 'publish_on': '2022-03-31 00:03', 'url': 'https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2022/ipa220331.zip'}, {'filename': 'ipa220407.zip', 'size': '129255064', 'publish_on': '2022-04-07 00:02', 'url': 'https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2022/ipa220407.zip'}, {'filename': 'ipa220414.zip', 'size': '146507150', 'publish_on': '2022-04-14 00:02', 'url': 'https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2022/ipa220414.zip'}, {'filename': 'ipa220421.zip', 'size': '174159340', 'publish_on': '2022-04-21 00:03', 'url': 'https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2022/ipa220421.zip'}, {'filename': 'ipa220428.zip', 'size': '161531147', 'publish_on': '2022-04-28 00:03', 'url': 'https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2022/ipa220428.zip'}, {'filename': 'ipa220505.zip', 'size': '193086465', 'publish_on': '2022-05-05 00:03', 'url': 'https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2022/ipa220505.zip'}, {'filename': 'ipa220512.zip', 'size': '186786342', 'publish_on': '2022-05-12 00:03', 'url': 'https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2022/ipa220512.zip'}, {'filename': 'ipa220519.zip', 'size': '188668577', 'publish_on': '2022-05-19 00:03', 'url': 'https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2022/ipa220519.zip'}, {'filename': 'ipa220526.zip', 'size': '166681024', 'publish_on': '2022-05-26 00:04', 'url': 'https://bulkdata.uspto.gov/data/patent/application/redbook/fulltext/2022/ipa220526.zip'}, {'filename': 'ipa220602.zip', 'size': '160026974', 'publish_on': '2022-06-02 00:03', 'url': 'https://bulkdata.uspto.gov/data/patent/application/redbook/full ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(files)
df.head(50)
# Out:
#                                     filename       size        publish_on  \
# 0                              ipa220106.zip  163074754  2022-01-06 08:22
# 1                              ipa220113.zip  159400377  2022-01-13 00:08
# 2                              ipa220120.zip  143972032  2022-01-20 00:17
# 3                              ipa220127.zip  172934663  2022-01-27 00:03
# 4                              ipa220203.zip  174222902  2022-02-03 06:14
# 5                              ipa220210.zip  162036524  2022-02-10 00:02
# 6                              ipa220217.zip  143576934  2022-02-17 00:02
# 7                              ipa220224.zip  158906116  2022-02-24 00:03
# 8                              ipa220303.zip  199151005  2022-03-03 00:03
# 9                              ipa220310.zip  170954180  2022-03-10 00:02
# 10                             ipa220317.zip  165355543  2022-03-17 00:03
# 11                             ipa220324.zip  190055188  2022-03-24 00:03
# 12                             ipa220331.zip  183482817  2022-03-31 00:03
# 13                             ipa220407.zip  129255064  2022-04-07 00:02
# 14                             ipa220414.zip  146507150  2022-04-14 00:02
# 15                             ipa220421.zip  174159340  2022-04-21 00:03
# 16                             ipa220428.zip  161531147  2022-04-28 00:03
# 17                             ipa220505.zip  193086465  2022-05-05 00:03
# 18                             ipa220512.zip  186786342  2022-05-12 00:03
# 19                             ipa220519.zip  188668577  2022-05-19 00:03
# 20                             ipa220526.zip  166681024  2022-05-26 00:04
# 21                             ipa220602.zip  160026974  2022-06-02 00:03
# 22                             ipa220609.zip  178954075  2022-06-09 00:03
# 23                             ipa220616.zip  178486656  2022-06-16 00:04
# 24                             ipa220623.zip  200998147  2022-06-23 00:04
# 25                             ipa220630.zip  182846371  2022-06-30 00:12
# 26                             ipa220707.zip  150307285  2022-07-07 00:03
# 27                             ipa220714.zip  161144422  2022-07-14 00:03
# 28                             ipa220721.zip  153121633  2022-07-21 00:06
# 29                             ipa220728.zip  158245397  2022-07-28 00:03
# 30                             ipa220804.zip  168040312  2022-08-04 00:04
# 31                             ipa220811.zip  178070939  2022-08-11 00:03
# 32                             ipa220818.zip  173622740  2022-08-18 00:03
# 33                             ipa220825.zip  174735525  2022-08-25 00:04
# 34                             ipa220901.zip  151971817  2022-09-01 00:05
# 35                             ipa220908.zip  163000419  2022-09-08 06:53
# 36                             ipa220915.zip  181154564  2022-09-15 00:04
# 37                             ipa220922.zip  166950024  2022-09-22 00:03
# 38                             ipa220929.zip  172310224  2022-09-29 00:02
# 39                             ipa221006.zip  193553652  2022-10-06 00:03
# 40  us-patent-application-v45-2021-08-30.dtd      58813  2021-12-07 14:03
# 41  us-patent-application-v46-2022-02-17.dtd      58605  2022-07-06 11:42
# 42   us-sequence-listing-v1_3-2020-10-08.dtd      12617  2022-01-05 07:59
#
#                                                   url
# 0   https://bulkdata.uspto.gov/data/patent/applica...
# 1   https://bulkdata.uspto.gov/data/patent/applica...
# 2   https://bulkdata.uspto.gov/data/patent/applica...
# 3   https://bulkdata.uspto.gov/data/patent/applica...
# 4   https://bulkdata.uspto.gov/data/patent/applica...
# 5   https://bulkdata.uspto.gov/data/patent/applica...
# 6   https://bulkdata.uspto.gov/data/patent/applica...
# 7   https://bulkdata.uspto.gov/data/patent/applica...
# 8   https://bulkdata.uspto.gov/data/patent/applica...
# 9   https://bulkdata.uspto.gov/data/patent/applica...
# 10  https://bulkdata.uspto.gov/data/patent/applica...
# 11  https://bulkdata.uspto.gov/data/patent/applica...
# 12  https://bulkdata.uspto.gov/data/patent/applica...
# 13  https://bulkdata.uspto.gov/data/patent/applica...
# 14  https://bulkdata.uspto.gov/data/patent/applica...
# 15  https://bulkdata.uspto.gov/data/patent/applica...
# 16  https://bulkdata.uspto.gov/data/patent/applica...
# 17  https://bulkdata.uspto.gov/data/patent/applica...
# 18  https://bulkdata.uspto.gov/data/patent/applica...
# 19  https://bulkdata.uspto.gov/data/patent/applica...
# 20  https://bulkdata.uspto.gov/data/patent/applica...
# 21  https://bulkdata.uspto.gov/data/patent/applica...
# 22  https://bulkdata.uspto.gov/data/patent/applica...
# 23  https://bulkdata.uspto.gov/data/patent/applica...
# 24  https://bulkdata.uspto.gov/data/patent/applica...
# 25  https://bulkdata.uspto.gov/data/patent/applica...
# 26  https://bulkdata.uspto.gov/data/patent/applica...
# 27  https://bulkdata.uspto.gov/data/patent/applica...
# 28  https://bulkdata.uspto.gov/data/patent/applica...
# 29  https://bulkdata.uspto.gov/data/patent/applica...
# 30  https://bulkdata.uspto.gov/data/patent/applica...
# 31  https://bulkdata.uspto.gov/data/patent/applica...
# 32  https://bulkdata.uspto.gov/data/patent/applica...
# 33  https://bulkdata.uspto.gov/data/patent/applica...
# 34  https://bulkdata.uspto.gov/data/patent/applica...
# 35  https://bulkdata.uspto.gov/data/patent/applica...
# 36  https://bulkdata.uspto.gov/data/patent/applica...
# 37  https://bulkdata.uspto.gov/data/patent/applica...
# 38  https://bulkdata.uspto.gov/data/patent/applica...
# 39  https://bulkdata.uspto.gov/data/patent/applica...
# 40  https://bulkdata.uspto.gov/data/patent/applica...
# 41  https://bulkdata.uspto.gov/data/patent/applica...
# 42  https://bulkdata.uspto.gov/data/patent/applica...

# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine('sqlite:///patent.db', echo=False)
df.to_sql('uspto_files', con=engine, if_exists='append')
